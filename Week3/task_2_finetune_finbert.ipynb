# %%
# !pip install -q transformers datasets accelerate scikit-learn

import os
import torch
import numpy as np
import pandas as pd
import transformers
print(transformers.__version__)
from datasets import Dataset, DatasetDict
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 4.57.3

# %%
# !pip install -U transformers accelerate datasets
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (4.57.3)
# Requirement already satisfied: accelerate in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (1.10.1)
# Requirement already satisfied: datasets in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (4.4.2)
# Requirement already satisfied: filelock in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: psutil in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from accelerate) (7.1.3)
# Requirement already satisfied: torch>=2.0.0 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from accelerate) (2.8.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: httpx<1.0.0 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from datasets) (0.70.18)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: anyio in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from httpx<1.0.0->datasets) (4.12.0)
# Requirement already satisfied: certifi in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from httpx<1.0.0->datasets) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from torch>=2.0.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.15.0)

# %%
import kagglehub
path = kagglehub.dataset_download("ankurzing/sentiment-analysis-for-financial-news")
csv_path = os.path.join(path, "all-data.csv")

df = pd.read_csv(csv_path, encoding="latin-1", sep=",", header=None, names=["label","text"])
df["label"] = df["label"].astype(str).str.strip().str.lower()
label_map_str2int = {"positive": 0, "negative": 1, "neutral": 2}
df["label_id"] = df["label"].map(label_map_str2int)
df = df.dropna(subset=["text","label_id"]).reset_index(drop=True)

train_df, temp_df = train_test_split(df, test_size=0.30, stratify=df["label_id"], random_state=42)
val_df, test_df = train_test_split(temp_df, test_size=0.50, stratify=temp_df["label_id"], random_state=42)

print("Train/Val/Test sizes:", len(train_df), len(val_df), len(test_df))
# Out:
# Train/Val/Test sizes: 3392 727 727

# %%
MODEL_NAME = "ProsusAI/finbert"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

def tokenize_batch(examples):
    return tokenizer(examples["text"], truncation=True, padding="max_length", max_length=128)

train_ds = Dataset.from_pandas(train_df[["text","label_id"]]).rename_column("label_id","label")
val_ds   = Dataset.from_pandas(val_df[["text","label_id"]]).rename_column("label_id","label")
test_ds  = Dataset.from_pandas(test_df[["text","label_id"]]).rename_column("label_id","label")

train_ds = train_ds.map(tokenize_batch, batched=True, remove_columns=["text"])
val_ds   = val_ds.map(tokenize_batch, batched=True, remove_columns=["text"])
test_ds  = test_ds.map(tokenize_batch, batched=True, remove_columns=["text"])
# Out:
# Map:   0%|          | 0/3392 [00:00<?, ? examples/s]
# Map:   0%|          | 0/727 [00:00<?, ? examples/s]
# Map:   0%|          | 0/727 [00:00<?, ? examples/s]

# %%
model = AutoModelForSequenceClassification.from_pretrained(MODEL_NAME, num_labels=3)

training_args = TrainingArguments(
    output_dir="./finbert_finetuned",
    do_eval=True,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=32,
    num_train_epochs=3,
    learning_rate=2e-5,
    weight_decay=0.01,
    logging_steps=100
)

# %%
def compute_metrics(eval_pred):
    preds, labels = eval_pred
    if preds.ndim == 2:
        preds = np.argmax(preds, axis=1)
    acc = accuracy_score(labels, preds)
    prec = precision_score(labels, preds, average="weighted", zero_division=0)
    rec = recall_score(labels, preds, average="weighted", zero_division=0)
    f1 = f1_score(labels, preds, average="weighted", zero_division=0)
    return {"accuracy": acc, "precision": prec, "recall": rec, "f1": f1}

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_ds,
    eval_dataset=val_ds,
    compute_metrics=compute_metrics,
)

# %%
trainer.train()
# Save the final model
trainer.save_model("./finbert_finetuned/best_model")
# Out:
# /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='636' max='636' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [636/636 16:37, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.342400</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.311100</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.149600</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.167900</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.088800</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.069200</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
metrics = trainer.evaluate(test_ds)
print("Test metrics:", metrics)
# Optionally get predictions and confusion matrix
preds = trainer.predict(test_ds)
preds_label = np.argmax(preds.predictions, axis=1)
from sklearn.metrics import confusion_matrix, classification_report
print(classification_report(test_df["label_id"], preds_label, target_names=["positive","negative","neutral"]))
print("Confusion matrix:\n", confusion_matrix(test_df["label_id"], preds_label))
# Out:
# /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Test metrics: {'eval_loss': 0.3674461245536804, 'eval_accuracy': 0.8954607977991746, 'eval_precision': 0.8967924660958725, 'eval_recall': 0.8954607977991746, 'eval_f1': 0.8958172764500236, 'eval_runtime': 22.9731, 'eval_samples_per_second': 31.646, 'eval_steps_per_second': 1.001, 'epoch': 3.0}
# /Users/dilipkumar/Library/Python/3.9/lib/python/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#               precision    recall  f1-score   support
#
#     positive       0.84      0.87      0.86       204
#     negative       0.87      0.92      0.89        91
#      neutral       0.93      0.90      0.91       432
#
#     accuracy                           0.90       727
#    macro avg       0.88      0.90      0.89       727
# weighted avg       0.90      0.90      0.90       727
#
# Confusion matrix:
#  [[178   3  23]
#  [  0  84   7]
#  [ 33  10 389]]

# %%
trainer.save_model("./finbert_finetuned/best_model")
tokenizer.save_pretrained("./finbert_finetuned/best_model")

# also save test_df for task 3
test_df.to_pickle("finbert_test_df.pkl")
